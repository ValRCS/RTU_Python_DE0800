# %% [markdown]
# <center><h1>Python Pandas Tutorial</h1><center>

# %% [markdown]
# ![Pandas](https://pandas.pydata.org/static/img/pandas_white.svg)

# %% [markdown]
# ## Pandas is Python Data Analysis Library
#
# pandas is an open source, BSD-licensed(can use for commercial means) library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language

# %% [markdown]
# * Widely used
# * Open Source
# * Active Development
# * Great Documentation
#
# Home Page: http://pandas.pydata.org/
#
# Using Documentation from: http://pandas.pydata.org/pandas-docs/stable/
#
# Fantastic Cheat Sheet: http://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
#
# Best book by Panda's creator Wes Kinney (2nd Edition 2017): http://shop.oreilly.com/product/0636920050896.do

# %%
try:
    import pandas as pd # pd is the standard naming alias for pandas
    print(f"Pandas version: {pd.__version__}")  #most serious packages include a version number
except ImportError:
    print("Pandas not found")
    print("Please install it using: pip install pandas")
# Pandas is a big package took a while...

# these are packages that are often used with pandas
import numpy as np # another big library with various numeric functions
print(f"Numpy version: {np.__version__}")
import matplotlib.pyplot as plt
# Out:
# Pandas version: 2.2.2
# Numpy version: 2.0.2

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ## Installing Pandas
#
# ### Check if it is already installed
#
# Pandas comes preinstalled on Google Colab, Anaconda, Github Codespaces and many other Python distributions.
#
# If you get ImportError: No module named pandas, then you need to install it using pip.
#
# You could install just plain pandas using command below:
# ```
# pip install pandas
# ```
#
# However, pandas offers extra features if you install it with the following command:
# ```python
# pip install pandas[all]
# ```
#
# Using [all] will install all the dependencies that pandas can use. Things like Excel, HDF5, SQL, Web Scraping, etc.
#
# You can also install selected dependencies like:
# ```python
# pip install pandas[sql, excel] # installs SQL and Excel dependencies
# ```
#
# Full explanation of dependencies can be found here: https://pandas.pydata.org/docs/getting_started/install.html#installing-optional-dependencies

# %%
# the main way we work with Pandas is through a DataFrame
# DataFrame is a tabular format basically a table. It is a 2D data structure with columns that can be of different data types
df = pd.read_csv("sample_data/california_housing_test.csv") # remember CSV is a huge format
# lots of options for read_csv method
df.head() # so with head we read first values in our dataframe, default is 5 if we want different then use say head(12) etcb
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
# print shape
print(f"Shape of the dataframe: {df.shape}")
# so I print a tuple with two values
# how many rows?
print(f"I have {df.shape[0]} rows")
# len will work too
print(f"I have {len(df)} rows")
# how many columns?
print(f"I have {df.shape[1]} columns")
# Out:
# Shape of the dataframe: (3000, 9)
# I have 3000 rows
# I have 3000 rows
# I have 9 columns

# %%
# print all column names
print(f"Columns in the dataframe: {df.columns}")
# Out:
# Columns in the dataframe: Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# lets get info on our columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
# so we have 9 columns of 3000 values each taking at least 8 bytes (64 bits)
# how much would that be?
9 * 3000 * 8 # so actually Pandas is very efficient here 211.1KB would be 216000 bytes roughly
# so tiny tiny overhead unlike regular Python
# Out:
# 216000

# %%
# pseudo-random sample of 7 rows
# we can do a seed for reproducibility
df.sample(7, random_state=2026) # this is a way to get a random sample of 7 rows, with specific values
# df.sample(7) # this would give you a different random sample each time
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 146     -117.23     32.75                23.0       2415.0           653.0
# 935     -122.49     37.75                48.0       2387.0           424.0
# 11      -119.12     35.85                37.0        736.0           166.0
# 2450    -118.46     34.26                33.0       1358.0           247.0
# 1055    -122.47     37.75                52.0       1598.0           285.0
# 2476    -119.53     36.65                43.0       1676.0           320.0
# 2688    -122.53     39.09                11.0       1264.0           271.0
#
#       population  households  median_income  median_house_value
# 146       1275.0       596.0         3.1389            101800.0
# 935       1041.0       408.0         3.7562            321200.0
# 11         564.0       138.0         2.4167             58300.0
# 2450       738.0       235.0         5.0947            210300.0
# ...

# %%
# the fundamental data structure in pandas is a dataframe
# think of it as a table with rows and columns
print("df is a type of:", type(df))
# Out:
# df is a type of: <class 'pandas.core.frame.DataFrame'>

# %%
# we might want to know the shape of our dataframe
df.shape  #this is property not a method so no ()
# so here we have 3000 rows and 9 columns
# Out:
# (3000, 9)

# %%
# we might want to get more information about our dataframe
df.info()  # this is a method so we need ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# ## Description of Dataframe
#
# We can use describe() method to get statistics of dataframe

# %%
df.describe() # this provides most basic statistics about the dataframe
# by default is uses numeric columns, but we can also include all columns
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.describe().T # just a simple transpose
# Out:
#                      count           mean            std         min  \
# longitude           3000.0    -119.589200       1.994936   -124.1800
# latitude            3000.0      35.635390       2.129670     32.5600
# housing_median_age  3000.0      28.845333      12.555396      1.0000
# total_rooms         3000.0    2599.578667    2155.593332      6.0000
# total_bedrooms      3000.0     529.950667     415.654368      2.0000
# population          3000.0    1402.798667    1030.543012      5.0000
# households          3000.0     489.912000     365.422710      2.0000
# median_income       3000.0       3.807272       1.854512      0.4999
# median_house_value  3000.0  205846.275000  113119.687470  22500.0000
#
#                            25%           50%            75%          max
# longitude             -121.810    -118.48500    -118.020000    -114.4900
# latitude                33.930      34.27000      37.690000      41.9200
# ...

# %%
# we can create a dateframe from Python List of Dictionaries
# keys will be column names
# values will be rows
# not all rows need to have all columns
mydata = [
    {"Name":"Valdis", "Food":"potatoes", "Speed":105.7, "Children":3, "hobby":"chess"},
    {"Name":"Liga", "Food":"soup", "Speed":92.7, "Children":3},
    {"Name":"Peter", "Food":"calliflowers", "Speed":155.7, "Children":7},
    {"Name":"Jānis", "Food":"kefir", "Speed":95.7, "Children":2, "Age": 55},
]
# note not every person has the same keys - that is fine, it can reflect real life data
mydata # just a list of dictionaries
# Out:
# [{'Name': 'Valdis',
#   'Food': 'potatoes',
#   'Speed': 105.7,
#   'Children': 3,
#   'hobby': 'chess'},
#  {'Name': 'Liga', 'Food': 'soup', 'Speed': 92.7, 'Children': 3},
#  {'Name': 'Peter', 'Food': 'calliflowers', 'Speed': 155.7, 'Children': 7},
#  {'Name': 'Jānis', 'Food': 'kefir', 'Speed': 95.7, 'Children': 2, 'Age': 55}]

# %%
type(mydata)
# Out:
# list

# %%
type(mydata[0]) #inside each list element we have a dictionary
# Out:
# dict

# %%
# so I can create a dataframe from a list of dictionaries
mydf = pd.DataFrame(mydata)
mydf # no need to use head or sample since we have only 4 rows
# Out:
#      Name          Food  Speed  Children  hobby   Age
# 0  Valdis      potatoes  105.7         3  chess   NaN
# 1    Liga          soup   92.7         3    NaN   NaN
# 2   Peter  calliflowers  155.7         7    NaN   NaN
# 3   Jānis         kefir   95.7         2    NaN  55.0

# %%
# notice Age column is missing for some rows, it is given as NaN

# %% [markdown]
# ## Saving Dataframe to CSV

# %%
mydf.to_csv("my_data.csv") # this will keep index column by default

# %%
# let me download automatically from google colab
from google.colab import files # this is Google Colab specific
# if I was running this locally I'd already have the data on my computer :0
files.download("my_data.csv")

# %%
# let's save the same data without index column (which is just a row number)
# also we want to use ; as separator also we want to use quotes for strings
mydf.to_csv("my_data_without_index.csv", index=False, sep=";", quotechar='"')
# TODO why did quotechar was not used? Is it only used when needed? Explore this yourself
# there are tens of different options for saving and loading CSV

# %%
# let's download from colab again
files.download("my_data_without_index.csv")

# %%
# data types inside mydf
mydf.info() # note Pandas 3+ starts using string instead of object when describing data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      4 non-null      object
#  1   Food      4 non-null      object
#  2   Speed     4 non-null      float64
#  3   Children  4 non-null      int64
#  4   hobby     1 non-null      object
#  5   Age       1 non-null      float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 324.0+ bytes

# %%
mydf.describe() # so describe only works for numeric columns by default
# Out:
#             Speed  Children   Age
# count    4.000000  4.000000   1.0
# mean   112.450000  3.750000  55.0
# std     29.364094  2.217356   NaN
# min     92.700000  2.000000  55.0
# 25%     94.950000  2.750000  55.0
# 50%    100.700000  3.000000  55.0
# 75%    118.200000  4.000000  55.0
# max    155.700000  7.000000  55.0

# %%
mydf.describe(include='all') # include objects and numeric types
# Out:
#           Name      Food       Speed  Children  hobby   Age
# count        4         4    4.000000  4.000000      1   1.0
# unique       4         4         NaN       NaN      1   NaN
# top     Valdis  potatoes         NaN       NaN  chess   NaN
# freq         1         1         NaN       NaN      1   NaN
# mean       NaN       NaN  112.450000  3.750000    NaN  55.0
# std        NaN       NaN   29.364094  2.217356    NaN   NaN
# min        NaN       NaN   92.700000  2.000000    NaN  55.0
# 25%        NaN       NaN   94.950000  2.750000    NaN  55.0
# 50%        NaN       NaN  100.700000  3.000000    NaN  55.0
# 75%        NaN       NaN  118.200000  4.000000    NaN  55.0
# max        NaN       NaN  155.700000  7.000000    NaN  55.0

# %%
mydf.describe(include='O') # object types only no numerics
# so this would make more sense than all
# Out:
#           Name      Food  hobby
# count        4         4      1
# unique       4         4      1
# top     Valdis  potatoes  chess
# freq         1         1      1

# %%
# Many Pandas functions / methods return a new dataframe
# describe returns a new dataframe of results
# so we can save it in a variable for further work
mydata_described = mydf.describe(include="all")
mydata_described # so I saved the dataframe describe result into a variable
# Out:
#           Name      Food       Speed  Children  hobby   Age
# count        4         4    4.000000  4.000000      1   1.0
# unique       4         4         NaN       NaN      1   NaN
# top     Valdis  potatoes         NaN       NaN  chess   NaN
# freq         1         1         NaN       NaN      1   NaN
# mean       NaN       NaN  112.450000  3.750000    NaN  55.0
# std        NaN       NaN   29.364094  2.217356    NaN   NaN
# min        NaN       NaN   92.700000  2.000000    NaN  55.0
# 25%        NaN       NaN   94.950000  2.750000    NaN  55.0
# 50%        NaN       NaN  100.700000  3.000000    NaN  55.0
# 75%        NaN       NaN  118.200000  4.000000    NaN  55.0
# max        NaN       NaN  155.700000  7.000000    NaN  55.0

# %%
mydata_described.to_csv("mystats.tsv", sep="\t") # so i can save to csv, or tsv or manyother formats

# %% [markdown]
# ## Getting a single column

# %%
mydf["Speed"] # so we can get a single column of data out of dataframe as Pandas Series
# underneath this structure is a Numpy array - basically a C array with some extra features
# Out:
# 0    105.7
# 1     92.7
# 2    155.7
# 3     95.7
# Name: Speed, dtype: float64

# %%
# type of column
type(mydf["Speed"]) # so we have a Pandas Series
# Out:
# pandas.core.series.Series

# %%
# there is a shorter way to access some column using . notation
# however this approach is not always possible, think why?
mydf.Speed # so column by name Speed - seems nice but why is this not so good?
# so this could lead to two type of errors
# the simple one is column with spaces
# the more dangerous one would be if column name matches some Pandas dataframe method
# Out:
# 0    105.7
# 1     92.7
# 2    155.7
# 3     95.7
# Name: Speed, dtype: float64

# %%
# So I can get statistics for a single column
mydf["Speed"].describe()
# Out:
# count      4.000000
# mean     112.450000
# std       29.364094
# min       92.700000
# 25%       94.950000
# 50%      100.700000
# 75%      118.200000
# max      155.700000
# Name: Speed, dtype: float64

# %%
# you can get a single column Dataframe then you need double brackets
mydf[["Speed"]]
# you can do more complex selections with multiple columns
# also dataframes have more options than numpy arrays
# Out:
#    Speed
# 0  105.7
# 1   92.7
# 2  155.7
# 3   95.7

# %%
# how about two columns
mydf[["Speed", "Children"]] # notice double brackets
# so we pass a list of column names we want to get out
# Out:
#    Speed  Children
# 0  105.7         3
# 1   92.7         3
# 2  155.7         7
# 3   95.7         2

# %%
# note selecting will give you shallow copy of the data
# meaning changing something in the selection will change the original dataframe
# if you want a copy you need to use .copy() method at the end

# %% [markdown]
# ## Open Data Sources
#
#
# *   https://data.europa.eu/en - European Union Open Data Portal
# *   https://data.gov/ - US Government Open Data
# *   https://www.kaggle.com/datasets -- need to have google account, but it is free
# *   https://data.gov.lv/eng - Latvian Open Data Portal, relatively small, but has some interesting datasets

# %% [markdown]
# ## Reading data from URL (CSV)

# %%
# we can read data directlly from web url address
url = "https://data.gov.lv/dati/dataset/633b5005-fe7f-44bd-b17c-4995d359f9b0/resource/975fb5a2-1be4-4183-b404-b32afe60c01a/download/kopa_cesu_pils_apmekletaju_veidi_pa_gadiem_menesiem.csv"
df = pd.read_csv(url) # Cēsis tourism data
df.head(3)# see  first 3 entrees
# Out:
#   Mēnesis;Ārzemnieku grupa;Latvijas grupa;Ģimene;Pāris;Viens;Draugi;Skolēnu grupa;Gads
# 0            Janvāris;492;110;576;385;9;322;189;2014
# 1              Februāris;69;94;90;94;15;145;196;2014
# 2               Marts;238;348;257;154;22;348;18;2014

# %%
# to fix encoding issues we can specify encoding
# to fix separator issues we can specify separator
df = pd.read_csv(url, sep=";",encoding="utf-8") # we download using ; as a separator for values (not the default comma)
df.head(3)# see  first 3 entrees
# Out:
#      Mēnesis  Ārzemnieku grupa  Latvijas grupa  Ģimene  Pāris  Viens  Draugi  \
# 0   Janvāris               492             110     576    385      9     322
# 1  Februāris                69              94      90     94     15     145
# 2      Marts               238             348     257    154     22     348
#
#    Skolēnu grupa  Gads
# 0            189  2014
# 1            196  2014
# 2             18  2014

# %%
df.columns
# Out:
# Index(['Mēnesis', 'Ārzemnieku grupa', 'Latvijas grupa', 'Ģimene', 'Pāris',
#        'Viens', 'Draugi', 'Skolēnu grupa', 'Gads'],
#       dtype='object')

# %% [markdown]
# ### Rename columns
#
# To rename columns we can use rename() method or we can can supply new column names when reading data from CSV

# %%
# so I can supply full new column names as a list
df.columns = ["Month", "Foreign group", "Latvian group", "Family", "Couple", "Single", "Friends", "Pupils", "Year"]
df.head()
# Out:
#        Month  Foreign group  Latvian group  Family  Couple  Single  Friends  \
# 0   Janvāris            492            110     576     385       9      322
# 1  Februāris             69             94      90      94      15      145
# 2      Marts            238            348     257     154      22      348
# 3    Aprīlis            332            254     517     258      41      295
# 4      Maijs           1257           2295     972     673      81      594
#
#    Pupils  Year
# 0     189  2014
# 1     196  2014
# 2      18  2014
# 3     185  2014
# 4     355  2014

# %%
# let me rename Foreign group to Foreigners
df.rename(columns={"Foreign group":"Foreigners"}, inplace=True) # inplace means we change the dataframe in this case df
df.head()
# Out:
#        Month  Foreigners  Latvian group  Family  Couple  Single  Friends  \
# 0   Janvāris         492            110     576     385       9      322
# 1  Februāris          69             94      90      94      15      145
# 2      Marts         238            348     257     154      22      348
# 3    Aprīlis         332            254     517     258      41      295
# 4      Maijs        1257           2295     972     673      81      594
#
#    Pupils  Year
# 0     189  2014
# 1     196  2014
# 2      18  2014
# 3     185  2014
# 4     355  2014

# %%
# let's change it back from Foreigners to Foreign group
# so we supply to columns a dictionary of changes we want to see
# {"Foreigners":"Foreign group"}
df.rename(columns={"Foreigners":"Foreign group"}, inplace=True)
df.head()
# Out:
#        Month  Foreign group  Latvian group  Family  Couple  Single  Friends  \
# 0   Janvāris            492            110     576     385       9      322
# 1  Februāris             69             94      90      94      15      145
# 2      Marts            238            348     257     154      22      348
# 3    Aprīlis            332            254     517     258      41      295
# 4      Maijs           1257           2295     972     673      81      594
#
#    Pupils  Year
# 0     189  2014
# 1     196  2014
# 2      18  2014
# 3     185  2014
# 4     355  2014

# %%
df.shape
# Out:
# (72, 9)

# %% [markdown]
# ## Column Operations

# %%
df.Year.describe() # note here I use the short syntax to select a column
# i use .Year not ["Year"] same result
# however . syntax will not work for ALL column names
# the column name should not have spaces or special characters
# also the column name should not interfere with DataFrame methods
# Out:
# count      72.00000
# mean     2016.50000
# std         1.71981
# min      2014.00000
# 25%      2015.00000
# 50%      2016.50000
# 75%      2018.00000
# max      2019.00000
# Name: Year, dtype: float64

# %%
df.Year.min(),df.Year.max() # this . syntax works with column names that are single word
# and do not conflict with dataframe methods
# some books say to avoid this syntax
# it is too handy to avoid
# be pragmatic
# Out:
# (2014, 2019)

# %%
# if our column names are not single words we can use df["Year"] syntax

df["Foreign group"].min(), df["Foreign group"].mean(), df["Foreign group"].max()
# also this syntax works with single word column names
# we can use this syntax for all columns
# also we can use variables instead of column names
# also if some column is named after pandas method then we can use this syntax
# for example if you have a column called describe then df.describe will not work..
# Out:
# (37, np.float64(918.8472222222222), 2300)

# %% [markdown]
# ## Two approaches IN PLACE and NOT IN PLACE when working with dataframe methods
#
# ### IN PLACE
#
# IN PLACE will modify the dataframe directly. It is faster and uses less memory, but it is not recommended for production code, because it is harder to debug and understand. Still very convenient for quick and dirty data analysis.

# %%
## We can renamed a specific column
df.rename(columns={"Foreign group":"Foreign"}, inplace=True) # inplace means we change the dataframe

# %% [markdown]
# ### OUT OF PLACE
#
# OUT OF PLACE will return a new dataframe, leaving the original dataframe unchanged. It is slower and uses more memory, but it is easier to understand and debug. It is recommended for production code.

# %%
# we can also rename out of place
df = df.rename(columns={"Latvian group":"Latvian"}) # this will not change the original dataframe
# but since we overwrite the df variable we will not have access to the original dataframe

# %%
df.describe() # numeric column stats
# Out:
#            Foreign      Latvian       Family       Couple      Single  \
# count    72.000000    72.000000    72.000000    72.000000   72.000000
# mean    918.847222   350.902778  1355.097222   939.875000  111.319444
# std     770.413711   333.511879  1360.394321   871.662422  101.333201
# min      37.000000     0.000000    90.000000    82.000000    9.000000
# 25%     258.000000   112.000000   446.250000   283.000000   38.250000
# 50%     533.000000   240.000000   840.000000   534.000000   65.000000
# 75%    1759.500000   525.250000  1518.250000  1287.500000  154.750000
# max    2300.000000  2295.000000  5086.000000  3044.000000  407.000000
#
#            Friends       Pupils        Year
# count    72.000000    72.000000    72.00000
# mean    803.263889   589.375000  2016.50000
# std     731.622623   661.560797     1.71981
# min     116.000000    16.000000  2014.00000
# 25%     298.750000   168.000000  2015.00000
# 50%     527.500000   281.500000  2016.50000
# ...

# %%
df.describe(include="O") # so for Month only since that is the only string object column
# Out:
#            Month
# count         72
# unique        12
# top     Janvāris
# freq           6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    72 non-null     object
#  1   Foreign  72 non-null     int64
#  2   Latvian  72 non-null     int64
#  3   Family   72 non-null     int64
#  4   Couple   72 non-null     int64
#  5   Single   72 non-null     int64
#  6   Friends  72 non-null     int64
#  7   Pupils   72 non-null     int64
#  8   Year     72 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 5.2+ KB

# %% [markdown]
# ## Row indexing
#
# In pandas we have two ways to index rows:
#
# *  iloc - index by integer position (this is number)
# *  loc - index by label (this could be number or string)

# %%
# this is numeric row lookup no matter what the real index looks like
df.iloc[40:45] # just using our regular Python syntax for sequences square brackets
# Out:
#          Month  Foreign  Latvian  Family  Couple  Single  Friends  Pupils  \
# 40       Maijs     1384      491    1627    1447     146     1403    2163
# 41      Jūnijs     1939      599    1690    1824     217     1213     226
# 42      Jūlijs     2030      456    5086    3044     324     2716     179
# 43     Augusts     2108      709    4569    2960     315     2896     252
# 44  Septembris     1645      583    1310    1376     170     1263    1154
#
#     Year
# 40  2017
# 41  2017
# 42  2017
# 43  2017
# 44  2017

# %%
# we could use also string index here they overlap
df.loc[40:45] # this is string based index so 45 is included here
# otherwise they are similar
# why?
# because our index is just a sequence of numbers
# generally you will want your index to be something more meaningful
# in this case it could be Year and Month combined
# Out:
#          Month  Foreign  Latvian  Family  Couple  Single  Friends  Pupils  \
# 40       Maijs     1384      491    1627    1447     146     1403    2163
# 41      Jūnijs     1939      599    1690    1824     217     1213     226
# 42      Jūlijs     2030      456    5086    3044     324     2716     179
# 43     Augusts     2108      709    4569    2960     315     2896     252
# 44  Septembris     1645      583    1310    1376     170     1263    1154
# 45    Oktobris      663      512    1339    1090     152     1137     838
#
#     Year
# 40  2017
# 41  2017
# 42  2017
# 43  2017
# 44  2017
# 45  2017

# %%
df.index = df.Month # note that means our index could have multiple same values that is fine in Pandas
df.head()
# Out:
#                Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Month
# Janvāris    Janvāris      492      110     576     385       9      322
# Februāris  Februāris       69       94      90      94      15      145
# Marts          Marts      238      348     257     154      22      348
# Aprīlis      Aprīlis      332      254     517     258      41      295
# Maijs          Maijs     1257     2295     972     673      81      594
#
#            Pupils  Year
# Month
# Janvāris      189  2014
# Februāris     196  2014
# Marts          18  2014
# Aprīlis       185  2014
# Maijs         355  2014

# %%
df.loc["Maijs"] # we utilize fact that our index is now a string of month names
# Out:
#        Month  Foreign  Latvian  Family  Couple  Single  Friends  Pupils  Year
# Month
# Maijs  Maijs     1257     2295     972     673      81      594     355  2014
# Maijs  Maijs     1316      769    1080     778      97      515    2398  2015
# Maijs  Maijs     1442      330    1405    1158     145      594    2814  2016
# Maijs  Maijs     1384      491    1627    1447     146     1403    2163  2017
# Maijs  Maijs     1225      240    1359    1064     168     1114    2231  2018
# Maijs  Maijs     1659      210     905     915     151      890    2305  2019

# %%
# there is also df.at command as well

# %% [markdown]
# ## Filtering Rows by Column Value

# %%
# if our index was not month names we could filter by Month column for Maijs
df[df.Month == "Maijs"] #so we write a filter and pass it to dataframe
# Out:
#        Month  Foreign  Latvian  Family  Couple  Single  Friends  Pupils  Year
# Month
# Maijs  Maijs     1257     2295     972     673      81      594     355  2014
# Maijs  Maijs     1316      769    1080     778      97      515    2398  2015
# Maijs  Maijs     1442      330    1405    1158     145      594    2814  2016
# Maijs  Maijs     1384      491    1627    1447     146     1403    2163  2017
# Maijs  Maijs     1225      240    1359    1064     168     1114    2231  2018
# Maijs  Maijs     1659      210     905     915     151      890    2305  2019

# %%
# how about filtering for months which containe letter r
df[df.Month.str.contains("r")] # so we use string method contains to filter
# containts could be used with any string column
# we could use longer filter
# Out:
#                  Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Month
# Janvāris      Janvāris      492      110     576     385       9      322
# Februāris    Februāris       69       94      90      94      15      145
# Marts            Marts      238      348     257     154      22      348
# Aprīlis        Aprīlis      332      254     517     258      41      295
# Septembris  Septembris     1142      599    1350    1036      86      655
# Oktobris      Oktobris      531      787    1007     454      43      338
# Novembris    Novembris      293      165     531     292      34      214
# Decembris    Decembris       78       99     200      82      10      133
# Janvāris      Janvāris      224       33     436     262      40      170
# Februāris    Februāris      269       89     190     172      30      248
# Marts            Marts      118       43     490     228      26      190
# Aprīlis        Aprīlis      497      250     475     252      52      293
# ...

# %%
df.iloc[2:5]  # 3rd to 5th row again numeric index even though our main index is now stringb
# Out:
#            Month  Foreign  Latvian  Family  Couple  Single  Friends  Pupils  \
# Month
# Marts      Marts      238      348     257     154      22      348      18
# Aprīlis  Aprīlis      332      254     517     258      41      295     185
# Maijs      Maijs     1257     2295     972     673      81      594     355
#
#          Year
# Month
# Marts    2014
# Aprīlis  2014
# Maijs    2014

# %%
df.loc[["Maijs","Jūnijs","Jūlijs"]] # notice double brackets again
# we passed a list of strings to our index
# again it works because our index is now a list of strings containing month names
# Out:
#          Month  Foreign  Latvian  Family  Couple  Single  Friends  Pupils  \
# Month
# Maijs    Maijs     1257     2295     972     673      81      594     355
# Maijs    Maijs     1316      769    1080     778      97      515    2398
# Maijs    Maijs     1442      330    1405    1158     145      594    2814
# Maijs    Maijs     1384      491    1627    1447     146     1403    2163
# Maijs    Maijs     1225      240    1359    1064     168     1114    2231
# Maijs    Maijs     1659      210     905     915     151      890    2305
# Jūnijs  Jūnijs     2041      573    1411     994     111      887     207
# Jūnijs  Jūnijs     1870      765    1515    1232     132      696     225
# Jūnijs  Jūnijs     2300      322    1793    1515     149      721     513
# Jūnijs  Jūnijs     1939      599    1690    1824     217     1213     226
# Jūnijs  Jūnijs     1985      344    1589    1298     193     1341    1072
# Jūnijs  Jūnijs     2091      207    1528    1385     240     1624     523
# ...

# %%
# we can filter by conditions inside
d2019 = df[df.Year == 2019] # so filter inside the dataframe
# then we assign the result to a new variable, it is a shallow copy so it is fast
d2019
# Out:
#                  Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Month
# Janvāris      Janvāris      338       85     509     280      39      329
# Februāris    Februāris      301      125     283     182      28      327
# Marts            Marts      293      112     448     348      40      354
# Aprīlis        Aprīlis      527      120     621     333      64      540
# Maijs            Maijs     1659      210     905     915     151      890
# Jūnijs          Jūnijs     2091      207    1528    1385     240     1624
# Jūlijs          Jūlijs     1753      420    3997    2648     365     2605
# Augusts        Augusts     2114      547    4971    3026     357     2394
# Septembris  Septembris     1369      482    1111    1213     181      886
# Oktobris      Oktobris      601      721    1587     886     121     1122
# Novembris    Novembris      300      206     738     394      64      408
# Decembris    Decembris      198      126     357     234      27      388
# ...

# %%
# filter by multiple conditions
big_pupils = df[(df.Year > 2015) & (df.Pupils > 1000)]  # notice the we use bit operator & instead of usual &
# & is a bit operator and it works on whole series of True/False values
# so we use & as AND for combining True False values in each filter
# we can also use | for OR when either filter would be good
big_pupils
# Out:
#                  Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Month
# Maijs            Maijs     1442      330    1405    1158     145      594
# Septembris  Septembris     1525      733    1349    1284     163      547
# Maijs            Maijs     1384      491    1627    1447     146     1403
# Septembris  Septembris     1645      583    1310    1376     170     1263
# Maijs            Maijs     1225      240    1359    1064     168     1114
# Jūnijs          Jūnijs     1985      344    1589    1298     193     1341
# Septembris  Septembris     1779      892    1003    1054     196     1350
# Oktobris      Oktobris      837      496    1122     792     108     1414
# Maijs            Maijs     1659      210     905     915     151      890
# Septembris  Septembris     1369      482    1111    1213     181      886
# Oktobris      Oktobris      601      721    1587     886     121     1122
#
#             Pupils  Year
# Month
# Maijs         2814  2016
# ...

# %%
df.Pupils > 1000 # this is Boolean series
# Out:
# Month
# Janvāris      False
# Februāris     False
# Marts         False
# Aprīlis       False
# Maijs         False
#               ...
# Augusts       False
# Septembris     True
# Oktobris       True
# Novembris     False
# Decembris     False
# Name: Pupils, Length: 72, dtype: bool

# %%
# groups = df[["Latvian group", "Foreign group"]]  # so groups dataframe has 2 columsn in a different order from original df
groups = df[["Foreign", "Latvian"]]  # so groups dataframe has 2 columns in a different order from original df
groups.head()
# Out:
#            Foreign  Latvian
# Month
# Janvāris       492      110
# Februāris       69       94
# Marts          238      348
# Aprīlis        332      254
# Maijs         1257     2295

# %% [markdown]
# ## Creating new columns - feature engineering
#
# In feature engineering we create new columns based on existing columns. This is done to improve model performance.

# %%
# creating a new column
# df["all_groups"] = df["Foreign group"] + df["Latvian group"]
df["all_groups"] = df["Foreign"] + df["Latvian"] # so we create a new column by adding two existing columns
df.head()
# Out:
#                Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Month
# Janvāris    Janvāris      492      110     576     385       9      322
# Februāris  Februāris       69       94      90      94      15      145
# Marts          Marts      238      348     257     154      22      348
# Aprīlis      Aprīlis      332      254     517     258      41      295
# Maijs          Maijs     1257     2295     972     673      81      594
#
#            Pupils  Year  all_groups
# Month
# Janvāris      189  2014         602
# Februāris     196  2014         163
# Marts          18  2014         586
# Aprīlis       185  2014         586
# Maijs         355  2014        3552

# %% [markdown]
# ## Create a numeric column from string column

# %%
# lets create a numeric column form month names
# we will use a dictionary to map month names to numbers
month_map = {"Janvāris":1, "Februāris":2, "Marts":3, "Aprīlis":4,
             "Maijs":5, "Jūnijs":6, "Jūlijs":7, "Augusts":8,
             "Septembris":9, "Oktobris":10, "Novembris":11, "Decembris":12}
             # you can use whatever mappings you need
# we create a new column by mapping month names to number
df["Month_num"] = df.Month.map(month_map) # so we use map method to map month names to numbers
df.head()
# Out:
#                Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Month
# Janvāris    Janvāris      492      110     576     385       9      322
# Februāris  Februāris       69       94      90      94      15      145
# Marts          Marts      238      348     257     154      22      348
# Aprīlis      Aprīlis      332      254     517     258      41      295
# Maijs          Maijs     1257     2295     972     673      81      594
#
#            Pupils  Year  all_groups  Month_num
# Month
# Janvāris      189  2014         602          1
# Februāris     196  2014         163          2
# Marts          18  2014         586          3
# Aprīlis       185  2014         586          4
# Maijs         355  2014        3552          5

# %%
# let us now create a new column from year and Month_num
# we can always cast any data to string
# lets add 0 in front of single digit months
df["Month_num"] = df.Month_num.astype(str).str.zfill(2) # so we use string method zfill to add 0 in front of single digit months
df["Year_Month"] = "Year_" + df.Year.astype(str) + "_" + df.Month_num.astype(str) # so we use string concatenation
df.head()
# Out:
#                Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Month
# Janvāris    Janvāris      492      110     576     385       9      322
# Februāris  Februāris       69       94      90      94      15      145
# Marts          Marts      238      348     257     154      22      348
# Aprīlis      Aprīlis      332      254     517     258      41      295
# Maijs          Maijs     1257     2295     972     673      81      594
#
#            Pupils  Year  all_groups Month_num    Year_Month
# Month
# Janvāris      189  2014         602        01  Year_2014_01
# Februāris     196  2014         163        02  Year_2014_02
# Marts          18  2014         586        03  Year_2014_03
# Aprīlis       185  2014         586        04  Year_2014_04
# Maijs         355  2014        3552        05  Year_2014_05

# %%
# Year_Month would make a good index
df.index = df.Year_Month # note here Month which was old index
# would move back to regular column
df.head()
# Out:
#                   Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01   Janvāris      492      110     576     385       9      322
# Year_2014_02  Februāris       69       94      90      94      15      145
# Year_2014_03      Marts      238      348     257     154      22      348
# Year_2014_04    Aprīlis      332      254     517     258      41      295
# Year_2014_05      Maijs     1257     2295     972     673      81      594
#
#               Pupils  Year  all_groups Month_num    Year_Month
# Year_Month
# Year_2014_01     189  2014         602        01  Year_2014_01
# Year_2014_02     196  2014         163        02  Year_2014_02
# Year_2014_03      18  2014         586        03  Year_2014_03
# Year_2014_04     185  2014         586        04  Year_2014_04
# Year_2014_05     355  2014        3552        05  Year_2014_05

# %% [markdown]
# ## Delete columns

# %%
# let us now drop some columns
df.drop(["Month_num", "Year_Month"], axis=1, inplace=True) # so we drop two columns
# axis=1 means we drop columns
# we would need to drop rows if we used axis=0
df.head()
# Out:
#                   Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01   Janvāris      492      110     576     385       9      322
# Year_2014_02  Februāris       69       94      90      94      15      145
# Year_2014_03      Marts      238      348     257     154      22      348
# Year_2014_04    Aprīlis      332      254     517     258      41      295
# Year_2014_05      Maijs     1257     2295     972     673      81      594
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602
# Year_2014_02     196  2014         163
# Year_2014_03      18  2014         586
# Year_2014_04     185  2014         586
# Year_2014_05     355  2014        3552

# %% [markdown]
# ## Visualizing Data - plotting

# %%
d2019.plot() # this will plot all numeric columns vs index
# by default pandas uses matplotlib to plot
# Out:
# <Axes: xlabel='Month'>

# %%
# plot only two columns against index
d2019.plot(y=["Single","Couple"])
# Out:
# <Axes: xlabel='Month'>

# %%
# https://pandas.pydata.org/docs/user_guide/visualization.html
# lets add y label

d2019.plot(kind ="bar",
           y=["Single","Couple"],
           title="2019 tourism",
           ylabel="Number of visitors")
# Out:
# <Axes: title={'center': '2019 tourism'}, xlabel='Month', ylabel='Number of visitors'>

# %%
# we can plot one column against another
d2019.plot(kind ="scatter", x="Month", y="Family")
# Out:
# <Axes: xlabel='Month', ylabel='Family'>

# %% [markdown]
# ## Sorting Data - sort_values()

# %%
# to sort we specify by which column(s) we want to sort
sorted_family = df.sort_values(by="Family") # here it is just one column
# it is also out of place - meaning we keep the original dataframe
sorted_family.head()
# Out:
#                   Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_02  Februāris       69       94      90      94      15      145
# Year_2018_02  Februāris      124       35     187     204      30      197
# Year_2015_02  Februāris      269       89     190     172      30      248
# Year_2014_12  Decembris       78       99     200      82      10      133
# Year_2016_12  Decembris      127      189     202     194      32      192
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_02     196  2014         163
# Year_2018_02     349  2018         159
# Year_2015_02     218  2015         358
# Year_2014_12     187  2014         177
# Year_2016_12      83  2016         316

# %%
# i create a new data frame i could have also overwritend the old df  as well or use in place option
sorted_family = df.sort_values(by="Family", ascending=False ) # so from the top
sorted_family.head()
# Out:
#                 Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2017_07   Jūlijs     2030      456    5086    3044     324     2716
# Year_2019_08  Augusts     2114      547    4971    3026     357     2394
# Year_2016_07   Jūlijs     2047      652    4679    3041     362     1701
# Year_2017_08  Augusts     2108      709    4569    2960     315     2896
# Year_2016_08  Augusts     1879      502    4485    2970     276     1126
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2017_07     179  2017        2486
# Year_2019_08     156  2019        2661
# Year_2016_07     216  2016        2699
# Year_2017_08     252  2017        2817
# Year_2016_08     173  2016        2381

# %%
# sorting by multiple columns, with different ascending parameters
multiple_sort = df.sort_values(by=["Year", "all_groups"], ascending=[False,True]) # we have now tiebreaks
# here we sort by year descending and then by all_groups ascending in case of tie
multiple_sort.head(15)
# Out:
#                    Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2019_12   Decembris      198      126     357     234      27      388
# Year_2019_03       Marts      293      112     448     348      40      354
# Year_2019_01    Janvāris      338       85     509     280      39      329
# Year_2019_02   Februāris      301      125     283     182      28      327
# Year_2019_11   Novembris      300      206     738     394      64      408
# Year_2019_04     Aprīlis      527      120     621     333      64      540
# Year_2019_10    Oktobris      601      721    1587     886     121     1122
# Year_2019_09  Septembris     1369      482    1111    1213     181      886
# Year_2019_05       Maijs     1659      210     905     915     151      890
# Year_2019_07      Jūlijs     1753      420    3997    2648     365     2605
# Year_2019_06      Jūnijs     2091      207    1528    1385     240     1624
# ...

# %%
df.head(10)
# Out:
#                    Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01    Janvāris      492      110     576     385       9      322
# Year_2014_02   Februāris       69       94      90      94      15      145
# Year_2014_03       Marts      238      348     257     154      22      348
# Year_2014_04     Aprīlis      332      254     517     258      41      295
# Year_2014_05       Maijs     1257     2295     972     673      81      594
# Year_2014_06      Jūnijs     2041      573    1411     994     111      887
# Year_2014_07      Jūlijs     1783      572    3117    1599     115     1130
# Year_2014_08     Augusts     2006      614    3938    1853     151     1372
# Year_2014_09  Septembris     1142      599    1350    1036      86      655
# Year_2014_10    Oktobris      531      787    1007     454      43      338
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602
# ...

# %%
# let's see which months had the least Single visitors
df[df.Single < 20]
# Out:
#                   Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01   Janvāris      492      110     576     385       9      322
# Year_2014_02  Februāris       69       94      90      94      15      145
# Year_2014_12  Decembris       78       99     200      82      10      133
# Year_2015_12  Decembris      116      112     361     210      19      116
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602
# Year_2014_02     196  2014         163
# Year_2014_12     187  2014         177
# Year_2015_12      87  2015         228

# %% [markdown]
# ## Modifying Data - apply()

# %%
# so here we filter by Single column and then we select that Single column
# we could have changed different column(s) as well
df.loc[df.Single < 20, 'Single'] += 10 # so for all cells in Single column that have value less than 20 we add 10
df.head()
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Out:
#                   Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01   Janvāris      492      110     576     385      19      322
# Year_2014_02  Februāris       69       94      90      94      25      145
# Year_2014_03      Marts      238      348     257     154      22      348
# Year_2014_04    Aprīlis      332      254     517     258      41      295
# Year_2014_05      Maijs     1257     2295     972     673      81      594
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602
# Year_2014_02     196  2014         163
# Year_2014_03      18  2014         586
# Year_2014_04     185  2014         586
# Year_2014_05     355  2014        3552

# %%
few_singles = df[df.Single < 20]
few_singles # no singles under 20 because we changed the original dataframe by adding 10 to all singles under 20
# Out:
#                  Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01  Janvāris      492      110     576     385      19      322
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602

# %%
few_singles.Single += 20
few_singles # nothing to change here
# Out:
# /tmp/ipykernel_7514/2729007667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   few_singles.Single += 20
#                  Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01  Janvāris      492      110     576     385      39      322
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602

# %%
df.head()
# Out:
#                   Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01   Janvāris      492      110     576     385      19      322
# Year_2014_02  Februāris       69       94      90      94      25      145
# Year_2014_03      Marts      238      348     257     154      22      348
# Year_2014_04    Aprīlis      332      254     517     258      41      295
# Year_2014_05      Maijs     1257     2295     972     673      81      594
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602
# Year_2014_02     196  2014         163
# Year_2014_03      18  2014         586
# Year_2014_04     185  2014         586
# Year_2014_05     355  2014        3552

# %% [markdown]
# ## Saving to Excel, pickle, json

# %%
# lets save to pickle - which is a binary format for pandas dataframes and other objects
# we can use pickle to save any python object - dictionaries, lists, etc
df.to_pickle("tourism.pkl")
# pickle is great if you want to save your data for later use

# %%
# we can also save to json
df.to_json("tourism.json", indent=4) # json is a text format
# the way pandas saves json is not very readable

# %%
# i am going to load pickle file back
df = pd.read_pickle("tourism.pkl")
df.head()
# Out:
#                   Month  Foreign  Latvian  Family  Couple  Single  Friends  \
# Year_Month
# Year_2014_01   Janvāris      492      110     576     385      19      322
# Year_2014_02  Februāris       69       94      90      94      25      145
# Year_2014_03      Marts      238      348     257     154      22      348
# Year_2014_04    Aprīlis      332      254     517     258      41      295
# Year_2014_05      Maijs     1257     2295     972     673      81      594
#
#               Pupils  Year  all_groups
# Year_Month
# Year_2014_01     189  2014         602
# Year_2014_02     196  2014         163
# Year_2014_03      18  2014         586
# Year_2014_04     185  2014         586
# Year_2014_05     355  2014        3552

# %%
# requires openpyxl package
# install with pip install openpyxl
df.to_excel("Cesis_tourism.xlsx")

# %%
# TODO show grouping and aggregation

# %%
# let us group df by month and find some statistics
# we will use groupby method
# we will group by month and then we will aggregate by sum
# this means we will sum all values for each numeric column besides the grouping column "Month"
# we will also reset index
# we will also sort by Pupils
grouped_df = df.groupby("Month").sum().reset_index().sort_values(by="Pupils", ascending=False)
grouped_df
# Out:
#          Month  Foreign  Latvian  Family  Couple  Single  Friends  Pupils  \
# 7        Maijs     8283     4335    7348    6035     788     5110   12266
# 11  Septembris     8981     3706    7390    7036     907     5440    8172
# 10    Oktobris     4016     3657    7766    4901     556     5079    7099
# 9    Novembris     1609      815    3128    1942     236     2092    3436
# 6       Jūnijs    12226     2810    9526    8248    1042     6482    2766
# 0      Aprīlis     2702     1099    3542    2209     332     2618    2743
# 3    Februāris      878      527    1361    1250     172     1373    1784
# 2    Decembris      832      849    1859    1148     190     1449    1013
# 5       Jūlijs    11512     3125   25179   15117    1703    12256     914
# 8        Marts     1293      701    2812    1691     229     1948     857
# 1      Augusts    12154     3076   24600   15917    1680    12373     701
# 4     Janvāris     1671      565    3056    2177     220     1615     684
#
# ...

# %%
# we can reach a conclustion that most pupils come in May, September and October
# why is that?
# pupils come during school trips, in summer there are no school trips
# in summer pupils could be coming with their families

# %%
# we can use other aggregation functions such as mean, count, min, max, etc
# you could even write your own aggregation functions
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html

# %%
# we can also group by multiple columns
# we will group by year and month - in this case kind of redundant
# we will use following aggregation functions: sum, mean, count, min, max
# we will also reset index
# we will also sort by Pupils
grouped_df = (df.groupby(["Year", "Month"])  # this will not do much because all Year Month combinations are unique in this dataframe
              .agg(["sum", "mean", "count", "min", "max"])
              .reset_index()
              .sort_values(by=("Pupils","sum"), ascending=False))
# i used parenthesis to break the code into multiple lines - little trick
# i had to use by=("Pupils","sum") because we have multiindex
grouped_df
# Out:
#     Year     Month Foreign                           Latvian               \
#                        sum    mean count   min   max     sum   mean count
# 31  2016     Maijs    1442  1442.0     1  1442  1442     330  330.0     1
# 19  2015     Maijs    1316  1316.0     1  1316  1316     769  769.0     1
# 67  2019     Maijs    1659  1659.0     1  1659  1659     210  210.0     1
# 55  2018     Maijs    1225  1225.0     1  1225  1225     240  240.0     1
# 43  2017     Maijs    1384  1384.0     1  1384  1384     491  491.0     1
# ..   ...       ...     ...     ...   ...   ...   ...     ...    ...   ...
# 28  2016  Janvāris     172   172.0     1   172   172     100  100.0     1
# 13  2015   Augusts    1896  1896.0     1  1896  1896     197  197.0     1
# 49  2018   Augusts    2151  2151.0     1  2151  2151     507  507.0     1
# 8   2014     Marts     238   238.0     1   238   238     348  348.0     1
# 5   2014    Jūlijs    1783  1783.0     1  1783  1783     572  572.0     1
#
# ...

# %% [markdown]
# ## Other visualization libraries
#
# *   Seaborn - https://seaborn.pydata.org/ - adds more features to matplotlib
# *   Bokeh - https://bokeh.pydata.org/en/latest/
# *   Plotly - https://plot.ly/python/  - interactive plots

# %%
# let us import plotly express
# if you are on colab you should haveit already
import plotly.express as px

# TODO next time plot some data with plotly express

# %%
# let's plot our pupils per month using plotly
fig = px.bar(df, x="Month", y=("Pupils"))
fig.show()
#
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# so for interactive visualizaitons explore Plotly library
